# %% [markdown]
# <a href="https://colab.research.google.com/github/yurialobao/deep-transfer-learning/blob/main/transfer_learning_horses_zebras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
